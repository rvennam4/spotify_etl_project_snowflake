# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /Users/ranjithvennam7/anaconda3/lib/python3.11/site-packages (2.25.0)
# Requirement already satisfied: redis>=3.5.3 in /Users/ranjithvennam7/anaconda3/lib/python3.11/site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in /Users/ranjithvennam7/anaconda3/lib/python3.11/site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/ranjithvennam7/anaconda3/lib/python3.11/site-packages (from spotipy) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ranjithvennam7/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ranjithvennam7/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ranjithvennam7/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2023.7.22)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='fcd5952a1c244ceea72727466fc9fd31', client_secret="dfa74b56bb454917892de2342c87c255")

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/4zzUm9eZmeb4t4nUCaNoo5"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
album_list= []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id, 'album_name':album_name, 'release_date':album_release_date, 'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'album_name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '7kFyd5oyJdVX2pIi6P4iHE',
#   'album_name': 'rosie',
#   'release_date': '2024-12-06',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/7kFyd5oyJdVX2pIi6P4iHE'},
#  {'album_id': '1qHV8NvD3illdTOBxHdzru',
#   'album_name': 'All',
#   'release_date': '2025-01-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1qHV8NvD3illdTOBxHdzru'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '3xFoV69r1WQqN0vgUOOOu3',
#   'album_name': 'Dig a Little Deeper',
#   'release_date': '2024-10-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3xFoV69r1WQqN0vgUOOOu3'},
#  {'album_id': '2I6LyArz82waG94e9V5B9d',
#   'album_name': 'Abracadabra',
#   'release_date': '2025-02-03',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2I6LyArz82waG94e9V5B9d'},
#  {'album_id': '0Z4TtKR05NtDn3QSTNR4ot',
#   'album_name': 'Revolution',
#   'release_date': '2024-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0Z4TtKR05NtDn3QSTNR4ot'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '0xjaP9pojggLose0ZqSzsW',
#   'album_name': 'No Second Chances',
#   'release_date': '2024-10-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0xjaP9pojggLose0ZqSzsW'},
#  {'album_id': '0hBRqPYPXhr1RkTDG3n4Mk',
#   'album_name': 'The Secret of Us (Deluxe)',
#   'release_date': '2024-10-18',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/0hBRqPYPXhr1RkTDG3n4Mk'},
#  {'album_id': '1RPAK2UlpvKasrJTTO1P7i',
#   'album_name': 'So Tell Me',
#   'release_date': '2024-10-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1RPAK2UlpvKasrJTTO1P7i'},
#  {'album_id': '3OxfaVgvTxUTy7276t7SPU',
#   'album_name': 'Hurry Up Tomorrow',
#   'release_date': '2025-01-31',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/3OxfaVgvTxUTy7276t7SPU'},
#  {'album_id': '6Scdn9H7XiMrrINZJ4JkZe',
#   'album_name': 'Energy',
#   'release_date': '2024-11-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Scdn9H7XiMrrINZJ4JkZe'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '6bTlsjg7Lsizw1mEiNAVaG',
#   'album_name': 'My Sunrise',
#   'release_date': '2024-10-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6bTlsjg7Lsizw1mEiNAVaG'},
#  {'album_id': '1Ss0ArMRr91m83mOgRBjSZ',
#   'album_name': 'GNX',
#   'release_date': '2024-11-21',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/1Ss0ArMRr91m83mOgRBjSZ'},
#  {'album_id': '7d0ZMNlNJdpp7VSolmu6Vz',
#   'album_name': 'Toxic',
#   'release_date': '2024-07-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7d0ZMNlNJdpp7VSolmu6Vz'},
#  {'album_id': '3uTpTaMOynCYKV5AtgeO2U',
#   'album_name': "This Wasn't Meant For You Anyway",
#   'release_date': '2024-06-21',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/3uTpTaMOynCYKV5AtgeO2U'},
#  {'album_id': '6RfeiWxyJEblhHdh1Qo8gv',
#   'album_name': 'Casanova',
#   'release_date': '2024-03-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6RfeiWxyJEblhHdh1Qo8gv'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '114JJGaaonCcmnhOoLHFUU',
#   'album_name': 'The Way We Move',
#   'release_date': '2024-04-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/114JJGaaonCcmnhOoLHFUU'},
#  {'album_id': '3OxfaVgvTxUTy7276t7SPU',
#   'album_name': 'Hurry Up Tomorrow',
#   'release_date': '2025-01-31',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/3OxfaVgvTxUTy7276t7SPU'},
#  {'album_id': '776Q4OJNfMl5maBaklmp6G',
#   'album_name': 'TO THE MOON',
#   'release_date': '2022-07-15',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/776Q4OJNfMl5maBaklmp6G'},
#  {'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'album_name': 'Good Luck, Babe!',
#   'release_date': '2024-04-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#  {'album_id': '2pBEKS7KZPKYXZTB0tCwik',
#   'album_name': 'Dirty South',
#   'release_date': '2024-03-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2pBEKS7KZPKYXZTB0tCwik'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'album_name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '34OahK8ZPeADCGzAoaFLna',
#   'album_name': 'Writing In The Dark',
#   'release_date': '2024-11-29',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/34OahK8ZPeADCGzAoaFLna'},
#  {'album_id': '1vNUD9sUBRHFFQiwYZm232',
#   'album_name': 'Loco',
#   'release_date': '2024-12-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1vNUD9sUBRHFFQiwYZm232'},
#  {'album_id': '1Ldt4mz70olknhLayjW0sw',
#   'album_name': 'I Miss Love',
#   'release_date': '2024-12-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Ldt4mz70olknhLayjW0sw'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '6CwZQYXrr4mAsD7Tj5FJzo',
#   'album_name': 'Мъгла',
#   'release_date': '2024-09-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6CwZQYXrr4mAsD7Tj5FJzo'},
#  {'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'album_name': 'Fireworks & Rollerblades',
#   'release_date': '2024-04-05',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/168CdR21lfn0TTyw1Pkdcm'},
#  {'album_id': '7k05YUAWJUMLJdhlPAsEjQ',
#   'album_name': 'Your Love',
#   'release_date': '2025-01-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7k05YUAWJUMLJdhlPAsEjQ'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'album_name': 'Not Like Us',
#   'release_date': '2024-05-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '3oaNRIimD438Qs5d0niECL',
#   'album_name': 'Seasons',
#   'release_date': '2025-01-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3oaNRIimD438Qs5d0niECL'},
#  {'album_id': '68CN2LzY8MoxO2udy2C22e',
#   'album_name': 'Sailor Song',
#   'release_date': '2024-07-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/68CN2LzY8MoxO2udy2C22e'},
#  {'album_id': '5zUBYi6iYNVwC58aH3UoMX',
#   'album_name': "Don't Cha",
#   'release_date': '2025-01-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5zUBYi6iYNVwC58aH3UoMX'},
#  {'album_id': '60UzB8mOCMpc7xkuJE6Bwc',
#   'album_name': 'Alligator Bites Never Heal',
#   'release_date': '2024-08-30',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/60UzB8mOCMpc7xkuJE6Bwc'},
#  {'album_id': '2PxQv4JznODhpEp45oEPda',
#   'album_name': "Sofia's Lullaby",
#   'release_date': '2024-11-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2PxQv4JznODhpEp45oEPda'},
#  {'album_id': '3OxfaVgvTxUTy7276t7SPU',
#   'album_name': 'Hurry Up Tomorrow',
#   'release_date': '2025-01-31',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/3OxfaVgvTxUTy7276t7SPU'},
#  {'album_id': '55hARqsFbn3LMV4nkLx9zo',
#   'album_name': 'Selfish',
#   'release_date': '2025-01-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/55hARqsFbn3LMV4nkLx9zo'},
#  {'album_id': '0XKconI47eiBP6qPYHsx9f',
#   'album_name': 'The Rise and Fall of a Midwest Princess',
#   'release_date': '2023-09-21',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0XKconI47eiBP6qPYHsx9f'},
#  {'album_id': '0K7sOpSep0RPz6jm6XqW3W',
#   'album_name': 'Give Me A Sign',
#   'release_date': '2025-01-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0K7sOpSep0RPz6jm6XqW3W'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '0TLn0q5L1HQglOq4a3Cvk6',
#   'album_name': 'Fake Love',
#   'release_date': '2025-01-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0TLn0q5L1HQglOq4a3Cvk6'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'album_name': 'GNX',
#   'release_date': '2024-11-22',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#  {'album_id': '6WIZLO4nISolz768bOMUuI',
#   'album_name': 'Lost Time',
#   'release_date': '2024-09-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6WIZLO4nISolz768bOMUuI'},
#  {'album_id': '5BoeqKVMi7D4S6U38rWjS4',
#   'album_name': '7 Dias',
#   'release_date': '2025-01-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5BoeqKVMi7D4S6U38rWjS4'},
#  {'album_id': '5ViP3YGQhyoxhC11KSVnZ4',
#   'album_name': 'Walk Alone',
#   'release_date': '2024-09-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5ViP3YGQhyoxhC11KSVnZ4'},
#  {'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'album_name': "I've Tried Everything But Therapy (Part 1)",
#   'release_date': '2023-09-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'},
#  {'album_id': '60McytknWBoI7zXLzDmdZC',
#   'album_name': 'Player Fitness',
#   'release_date': '2025-01-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/60McytknWBoI7zXLzDmdZC'},
#  {'album_id': '0aX0UXrHG2ceYIxTQcqJdA',
#   'album_name': 'Cosa Nuestra',
#   'release_date': '2024-11-15',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/0aX0UXrHG2ceYIxTQcqJdA'},
#  {'album_id': '4JlXzhm2cQKEvEai7C5lfp',
#   'album_name': 'All My Love',
#   'release_date': '2024-09-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4JlXzhm2cQKEvEai7C5lfp'},
#  {'album_id': '4sD1qg4jwTZR4mvR4Iflk5',
#   'album_name': 'Strange Trails',
#   'release_date': '2015-04-06',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4sD1qg4jwTZR4mvR4Iflk5'},
#  {'album_id': '5aTBeL8zIsRNccwTzoJvPX',
#   'album_name': 'Somebody',
#   'release_date': '2025-01-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5aTBeL8zIsRNccwTzoJvPX'},
#  {'album_id': '5aelly3dAJd7yZlgUHpLBw',
#   'album_name': 'blue',
#   'release_date': '2024-08-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5aelly3dAJd7yZlgUHpLBw'},
#  {'album_id': '5yyID2DMj3mrsJfWGwFSpF',
#   'album_name': 'Just Fine',
#   'release_date': '2024-10-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5yyID2DMj3mrsJfWGwFSpF'},
#  {'album_id': '1fOTqAU8mRMHlmOaHMqsge',
#   'album_name': 'Sports car',
#   'release_date': '2025-01-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1fOTqAU8mRMHlmOaHMqsge'},
#  {'album_id': '0pbDdpYUBFKam7ETsvtYZk',
#   'album_name': 'Come Over',
#   'release_date': '2024-10-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0pbDdpYUBFKam7ETsvtYZk'},
#  {'album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'album_name': 'Si Antes Te Hubiera Conocido',
#   'release_date': '2024-06-21',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5ylbxH7EqpsmHZCRuiYewS'},
#  {'album_id': '6cEWg3FcEj8lfcKIXirUFo',
#   'album_name': 'Guy For That',
#   'release_date': '2024-11-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6cEWg3FcEj8lfcKIXirUFo'},
#  {'album_id': '0U28P0QVB1QRxpqp5IHOlH',
#   'album_name': 'CHROMAKOPIA',
#   'release_date': '2024-10-28',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0U28P0QVB1QRxpqp5IHOlH'},
#  {'album_id': '6yMPvigl9CtHmrrmAcqDZ0',
#   'album_name': 'Sacrifice',
#   'release_date': '2024-11-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6yMPvigl9CtHmrrmAcqDZ0'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '1AJrKOveFbjatoROyWe4nU',
#   'album_name': 'Secret Lover',
#   'release_date': '2024-11-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1AJrKOveFbjatoROyWe4nU'},
#  {'album_id': '5cQfpT5TqmekHpZqYDcGTL',
#   'album_name': 'ROSONES',
#   'release_date': '2024-12-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5cQfpT5TqmekHpZqYDcGTL'},
#  {'album_id': '6pOHHPn9dCK0uxnzYcgE0B',
#   'album_name': 'Daisies and Roses',
#   'release_date': '2025-01-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6pOHHPn9dCK0uxnzYcgE0B'},
#  {'album_id': '0aX0UXrHG2ceYIxTQcqJdA',
#   'album_name': 'Cosa Nuestra',
#   'release_date': '2024-11-15',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/0aX0UXrHG2ceYIxTQcqJdA'},
#  {'album_id': '1bWOmZBfzhaOlKw3r4uWA6',
#   'album_name': 'Happily Ever After',
#   'release_date': '2024-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1bWOmZBfzhaOlKw3r4uWA6'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '7zq2kZeVwanGp6Xs0BgcVU',
#   'album_name': 'Hero',
#   'release_date': '2024-10-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7zq2kZeVwanGp6Xs0BgcVU'},
#  {'album_id': '3wn07z4XXQZsHyyGETCOT9',
#   'album_name': '100 Greatest R&B',
#   'release_date': '2019-11-22',
#   'total_tracks': 100,
#   'url': 'https://open.spotify.com/album/3wn07z4XXQZsHyyGETCOT9'},
#  {'album_id': '1SAbkSimj7tLvE079ExzQm',
#   'album_name': 'Separation Song',
#   'release_date': '2024-11-29',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/1SAbkSimj7tLvE079ExzQm'},
#  {'album_id': '2nkto6YNI4rUYTLqEwWJ3o',
#   'album_name': 'Flower Boy',
#   'release_date': '2017-07-21',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/2nkto6YNI4rUYTLqEwWJ3o'},
#  {'album_id': '4cNanj8nA2FZhmEsBqn4jw',
#   'album_name': 'THROW DAT',
#   'release_date': '2024-10-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4cNanj8nA2FZhmEsBqn4jw'},
#  {'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'album_name': 'I Love You.',
#   'release_date': '2013-04-22',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4xkM0BwLM9H2IUcbYzpcBI'},
#  {'album_id': '3KGBPkfgmLpEPiH24aKrxs',
#   'album_name': 'Forget My Eyes',
#   'release_date': '2024-09-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3KGBPkfgmLpEPiH24aKrxs'},
#  {'album_id': '6ZG5lRT77aJ3btmArcykra',
#   'album_name': 'Parachutes',
#   'release_date': '2000-07-10',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#  {'album_id': '6NdEcwKVIXJrEdMW4aDuK1',
#   'album_name': 'Light',
#   'release_date': '2024-11-22',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/6NdEcwKVIXJrEdMW4aDuK1'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'album_name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '3rpT0m0NM5RFerjhTp2FB3',
#   'album_name': 'Since You Left',
#   'release_date': '2024-08-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3rpT0m0NM5RFerjhTp2FB3'},
#  {'album_id': '36P07bti6xD99o7S1acmin',
#   'album_name': 'Brat and it’s completely different but also still brat',
#   'release_date': '2024-10-11',
#   'total_tracks': 34,
#   'url': 'https://open.spotify.com/album/36P07bti6xD99o7S1acmin'},
#  {'album_id': '7kDv3WTZCO9Vtv2PIUFXow',
#   'album_name': 'Feelings Of Hope',
#   'release_date': '2024-11-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7kDv3WTZCO9Vtv2PIUFXow'},
#  {'album_id': '0sWJ3v0FROzcNzyjNYUs6t',
#   'album_name': 'LA CIUDAD',
#   'release_date': '2024-12-24',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/0sWJ3v0FROzcNzyjNYUs6t'},
#  {'album_id': '4B884BtczVZf67Bi8r4s5J',
#   'album_name': 'Naive Heart',
#   'release_date': '2024-11-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4B884BtczVZf67Bi8r4s5J'},
#  {'album_id': '3awd1TKrdd3emCecvza61j',
#   'album_name': 'Love Hangover (feat. Dominic Fike)',
#   'release_date': '2025-01-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3awd1TKrdd3emCecvza61j'},
#  {'album_id': '6f9NiLFbTBsCT5qYJR6UKW',
#   'album_name': 'Rich Man',
#   'release_date': '2024-09-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6f9NiLFbTBsCT5qYJR6UKW'},
#  {'album_id': '0mc2gCpCL7rXvz6HGR6evD',
#   'album_name': "I'm The Problem",
#   'release_date': '2025-01-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0mc2gCpCL7rXvz6HGR6evD'},
#  {'album_id': '5Dwp1haDPUGvj20rBrqWxo',
#   'album_name': 'Echoing Through the Night',
#   'release_date': '2024-11-08',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/5Dwp1haDPUGvj20rBrqWxo'},
#  {'album_id': '1Kg8dxL57VOCutWzOqYYff',
#   'album_name': 'In Love With A Memory',
#   'release_date': '2025-01-28',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1Kg8dxL57VOCutWzOqYYff'},
#  {'album_id': '1cTc7MU1FhaCiTdRZEsaKh',
#   'album_name': 'Heart Bleed',
#   'release_date': '2024-11-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1cTc7MU1FhaCiTdRZEsaKh'},
#  {'album_id': '2XgZQ0IFRwZcqsk6RWReKS',
#   'album_name': 'In Waves (Deluxe)',
#   'release_date': '2025-01-29',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/2XgZQ0IFRwZcqsk6RWReKS'},
#  {'album_id': '3SDiCnxRfqt4drbEO7B93x',
#   'album_name': 'Found It In You',
#   'release_date': '2024-11-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3SDiCnxRfqt4drbEO7B93x'},
#  {'album_id': '3kP4QpDTvR9jCHnlQdsKFV',
#   'album_name': 'Blick Sum (feat. Playboi Carti)',
#   'release_date': '2025-01-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3kP4QpDTvR9jCHnlQdsKFV'},
#  {'album_id': '6N5gHO70de3U2zjkkJgatP',
#   'album_name': 'Midnight Conversations',
#   'release_date': '2024-08-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6N5gHO70de3U2zjkkJgatP'},
#  {'album_id': '1EPbWEhg5ljGLxp4TKbtwq',
#   'album_name': 'CRUZ',
#   'release_date': '2025-01-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1EPbWEhg5ljGLxp4TKbtwq'},
#  {'album_id': '1n5TFOqz5Fc5FaaeAsSzkP',
#   'album_name': "I'm Gone",
#   'release_date': '2024-11-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1n5TFOqz5Fc5FaaeAsSzkP'},
#  {'album_id': '04ePsbupvv5MPe8CamGhKZ',
#   'album_name': 'LOVE LOOKS PRETTY ON YOU',
#   'release_date': '2025-01-31',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/04ePsbupvv5MPe8CamGhKZ'},
#  {'album_id': '7rwrBwnb5aLkcoOSjs7CUp',
#   'album_name': 'Pass Me By',
#   'release_date': '2024-06-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7rwrBwnb5aLkcoOSjs7CUp'}]

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '5S9g7xtHqKL3NQYfOdBBPO',
#   'artist_name': 'Zoe Ray',
#   'external_url': 'https://api.spotify.com/v1/artists/5S9g7xtHqKL3NQYfOdBBPO'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '2nl7s3ZFvCqP7yZmoh9vwA',
#   'artist_name': 'Daniel Quick',
#   'external_url': 'https://api.spotify.com/v1/artists/2nl7s3ZFvCqP7yZmoh9vwA'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0FJgCEndUymtcCw641LnxX',
#   'artist_name': '23 TheMiracle',
#   'external_url': 'https://api.spotify.com/v1/artists/0FJgCEndUymtcCw641LnxX'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '2tN8kUo2uPtAccoXS3mcMz',
#   'artist_name': 'Jordi Highdale',
#   'external_url': 'https://api.spotify.com/v1/artists/2tN8kUo2uPtAccoXS3mcMz'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'external_url': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '5ixDiP5FqojNGMn5buQdbm',
#   'artist_name': 'Yara',
#   'external_url': 'https://api.spotify.com/v1/artists/5ixDiP5FqojNGMn5buQdbm'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '06w2Oa0X7swnlzqzUN7sa0',
#   'artist_name': 'Coral Cross',
#   'external_url': 'https://api.spotify.com/v1/artists/06w2Oa0X7swnlzqzUN7sa0'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '2PQfMQxXtI0AwMdLyd1dC9',
#   'artist_name': 'Silvi Di',
#   'external_url': 'https://api.spotify.com/v1/artists/2PQfMQxXtI0AwMdLyd1dC9'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '046yQ380N3R1xFRIrf1mwc',
#   'artist_name': 'KayOrAlpha',
#   'external_url': 'https://api.spotify.com/v1/artists/046yQ380N3R1xFRIrf1mwc'},
#  {'artist_id': '67FB4n52MgexGQIG8s0yUH',
#   'artist_name': 'Lola Young',
#   'external_url': 'https://api.spotify.com/v1/artists/67FB4n52MgexGQIG8s0yUH'},
#  {'artist_id': '6PqW2KNWiTMasdfl7ZH95h',
#   'artist_name': 'Vain Villain Society',
#   'external_url': 'https://api.spotify.com/v1/artists/6PqW2KNWiTMasdfl7ZH95h'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '046yQ380N3R1xFRIrf1mwc',
#   'artist_name': 'KayOrAlpha',
#   'external_url': 'https://api.spotify.com/v1/artists/046yQ380N3R1xFRIrf1mwc'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '2KjQqTTZkvNyK9Q2DdNa6d',
#   'artist_name': 'Bobby Blaque',
#   'external_url': 'https://api.spotify.com/v1/artists/2KjQqTTZkvNyK9Q2DdNa6d'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '046yQ380N3R1xFRIrf1mwc',
#   'artist_name': 'KayOrAlpha',
#   'external_url': 'https://api.spotify.com/v1/artists/046yQ380N3R1xFRIrf1mwc'},
#  {'artist_id': '5E4JRe236vbTvj7lL2qe0c',
#   'artist_name': 'JusJugga',
#   'external_url': 'https://api.spotify.com/v1/artists/5E4JRe236vbTvj7lL2qe0c'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '0hScv0pHm7SNbXjVxj4kF4',
#   'artist_name': 'Titus Drott',
#   'external_url': 'https://api.spotify.com/v1/artists/0hScv0pHm7SNbXjVxj4kF4'},
#  {'artist_id': '6pV5zH2LzjOUHaAvENdMMa',
#   'artist_name': 'Neton Vega',
#   'external_url': 'https://api.spotify.com/v1/artists/6pV5zH2LzjOUHaAvENdMMa'},
#  {'artist_id': '5vCn4cc4Ww3QutKZxfcmq3',
#   'artist_name': 'CLYDE',
#   'external_url': 'https://api.spotify.com/v1/artists/5vCn4cc4Ww3QutKZxfcmq3'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '4A22rmC4eVgBXnuR1XiuBp',
#   'artist_name': 'Tsveta',
#   'external_url': 'https://api.spotify.com/v1/artists/4A22rmC4eVgBXnuR1XiuBp'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_url': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '2S1qObOrNfv8aYliwgGeFO',
#   'artist_name': 'Linda Englund',
#   'external_url': 'https://api.spotify.com/v1/artists/2S1qObOrNfv8aYliwgGeFO'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '1yAAk10PqWfpEom1wNswrf',
#   'artist_name': 'Edina Balint',
#   'external_url': 'https://api.spotify.com/v1/artists/1yAAk10PqWfpEom1wNswrf'},
#  {'artist_id': '1iCnM8foFssWlPRLfAbIwo',
#   'artist_name': 'Gigi Perez',
#   'external_url': 'https://api.spotify.com/v1/artists/1iCnM8foFssWlPRLfAbIwo'},
#  {'artist_id': '62IQyh50bOxyfJeQVY3G7r',
#   'artist_name': 'Love & Axel',
#   'external_url': 'https://api.spotify.com/v1/artists/62IQyh50bOxyfJeQVY3G7r'},
#  {'artist_id': '3sBTDJE6bwya7VW8nusnS2',
#   'artist_name': 'ABEYBABY',
#   'external_url': 'https://api.spotify.com/v1/artists/3sBTDJE6bwya7VW8nusnS2'},
#  {'artist_id': '4QcGYSgeMKnnxyLWXgb8Is',
#   'artist_name': 'Algorytm',
#   'external_url': 'https://api.spotify.com/v1/artists/4QcGYSgeMKnnxyLWXgb8Is'},
#  {'artist_id': '4E2rKHVDssGJm2SCDOMMJB',
#   'artist_name': 'Doechii',
#   'external_url': 'https://api.spotify.com/v1/artists/4E2rKHVDssGJm2SCDOMMJB'},
#  {'artist_id': '0FJgCEndUymtcCw641LnxX',
#   'artist_name': '23 TheMiracle',
#   'external_url': 'https://api.spotify.com/v1/artists/0FJgCEndUymtcCw641LnxX'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '7FNnA9vBm6EKceENgCGRMb',
#   'artist_name': 'Anitta',
#   'external_url': 'https://api.spotify.com/v1/artists/7FNnA9vBm6EKceENgCGRMb'},
#  {'artist_id': '1SYRpAvfTA3X2nnNmDRwiw',
#   'artist_name': 'Golden Fez',
#   'external_url': 'https://api.spotify.com/v1/artists/1SYRpAvfTA3X2nnNmDRwiw'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '2HhnzleZluv96odryD8CyN',
#   'artist_name': 'Eren Senbay',
#   'external_url': 'https://api.spotify.com/v1/artists/2HhnzleZluv96odryD8CyN'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '0fHAJrdOubsQ6TiUmmR34c',
#   'artist_name': 'Paul BornaStar',
#   'external_url': 'https://api.spotify.com/v1/artists/0fHAJrdOubsQ6TiUmmR34c'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '1jiZvw42D4oquLl24x2VWV',
#   'artist_name': 'Lefty Gunplay',
#   'external_url': 'https://api.spotify.com/v1/artists/1jiZvw42D4oquLl24x2VWV'},
#  {'artist_id': '5vCn4cc4Ww3QutKZxfcmq3',
#   'artist_name': 'CLYDE',
#   'external_url': 'https://api.spotify.com/v1/artists/5vCn4cc4Ww3QutKZxfcmq3'},
#  {'artist_id': '6Sbl0NT50roqWvy746MfVf',
#   'artist_name': 'Gabito Ballesteros',
#   'external_url': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'external_url': 'https://api.spotify.com/v1/artists/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '2NfEnoexAAiBUCrAE2X1kn',
#   'artist_name': 'Marcus Lindeberg',
#   'external_url': 'https://api.spotify.com/v1/artists/2NfEnoexAAiBUCrAE2X1kn'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'external_url': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '3sBTDJE6bwya7VW8nusnS2',
#   'artist_name': 'ABEYBABY',
#   'external_url': 'https://api.spotify.com/v1/artists/3sBTDJE6bwya7VW8nusnS2'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'external_url': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '3uhRr7RwOR4JZnf4CPD9Zx',
#   'artist_name': 'Linn Willner',
#   'external_url': 'https://api.spotify.com/v1/artists/3uhRr7RwOR4JZnf4CPD9Zx'},
#  {'artist_id': '6ltzsmQQbmdoHHbLZ4ZN25',
#   'artist_name': 'Lord Huron',
#   'external_url': 'https://api.spotify.com/v1/artists/6ltzsmQQbmdoHHbLZ4ZN25'},
#  {'artist_id': '3Tt6uqSiDr4QMC8efjaIKG',
#   'artist_name': 'Winterland',
#   'external_url': 'https://api.spotify.com/v1/artists/3Tt6uqSiDr4QMC8efjaIKG'},
#  {'artist_id': '6zO1dZ40fTZ5hY9NnnRJSk',
#   'artist_name': 'yung kai',
#   'external_url': 'https://api.spotify.com/v1/artists/6zO1dZ40fTZ5hY9NnnRJSk'},
#  {'artist_id': '626GstAFQ0xlt6q7GXEAFB',
#   'artist_name': 'Hardnight',
#   'external_url': 'https://api.spotify.com/v1/artists/626GstAFQ0xlt6q7GXEAFB'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '62IQyh50bOxyfJeQVY3G7r',
#   'artist_name': 'Love & Axel',
#   'external_url': 'https://api.spotify.com/v1/artists/62IQyh50bOxyfJeQVY3G7r'},
#  {'artist_id': '1x9L1nTxxAZnm0INkNxRxk',
#   'artist_name': 'Ketchum',
#   'external_url': 'https://api.spotify.com/v1/artists/1x9L1nTxxAZnm0INkNxRxk'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '3psaNfYQbM1jMXfeNC0ZI2',
#   'artist_name': 'The Songbayteam',
#   'external_url': 'https://api.spotify.com/v1/artists/3psaNfYQbM1jMXfeNC0ZI2'},
#  {'artist_id': '0miRmIqgGm833WCXx3UMV4',
#   'artist_name': 'Sean Pisano',
#   'external_url': 'https://api.spotify.com/v1/artists/0miRmIqgGm833WCXx3UMV4'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'external_url': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '67FB4n52MgexGQIG8s0yUH',
#   'artist_name': 'Lola Young',
#   'external_url': 'https://api.spotify.com/v1/artists/67FB4n52MgexGQIG8s0yUH'},
#  {'artist_id': '1SYRpAvfTA3X2nnNmDRwiw',
#   'artist_name': 'Golden Fez',
#   'external_url': 'https://api.spotify.com/v1/artists/1SYRpAvfTA3X2nnNmDRwiw'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '5t7plpGc3Pd33pZjVj30Rg',
#   'artist_name': 'Lex Ferrari',
#   'external_url': 'https://api.spotify.com/v1/artists/5t7plpGc3Pd33pZjVj30Rg'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'external_url': 'https://api.spotify.com/v1/artists/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '7pBIRDdABfLAPB9JzTKIMf',
#   'artist_name': 'Izzy Maher',
#   'external_url': 'https://api.spotify.com/v1/artists/7pBIRDdABfLAPB9JzTKIMf'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'external_url': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '5lwmRuXgjX8xIwlnauTZIP',
#   'artist_name': 'Romeo Santos',
#   'external_url': 'https://api.spotify.com/v1/artists/5lwmRuXgjX8xIwlnauTZIP'},
#  {'artist_id': '6AGzjBliBjFQkAMCtM4kNV',
#   'artist_name': 'noran',
#   'external_url': 'https://api.spotify.com/v1/artists/6AGzjBliBjFQkAMCtM4kNV'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '0hScv0pHm7SNbXjVxj4kF4',
#   'artist_name': 'Titus Drott',
#   'external_url': 'https://api.spotify.com/v1/artists/0hScv0pHm7SNbXjVxj4kF4'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '7qQlMOUgI0Sg4YVW4YkaUW',
#   'artist_name': 'Wonderfun',
#   'external_url': 'https://api.spotify.com/v1/artists/7qQlMOUgI0Sg4YVW4YkaUW'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'external_url': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '1U1el3k54VvEUzo3ybLPlM',
#   'artist_name': 'Kali Uchis',
#   'external_url': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM'},
#  {'artist_id': '2xTLvxdOIlfWVXV2ovn3oi',
#   'artist_name': 'Matt Fella',
#   'external_url': 'https://api.spotify.com/v1/artists/2xTLvxdOIlfWVXV2ovn3oi'},
#  {'artist_id': '4FvWb2j1ZllzhNzVYYzcMA',
#   'artist_name': 'The Honorable SoLo D',
#   'external_url': 'https://api.spotify.com/v1/artists/4FvWb2j1ZllzhNzVYYzcMA'},
#  {'artist_id': '0NawbOjd35MZ0vbymRBsV6',
#   'artist_name': 'MiamiSportsMusic',
#   'external_url': 'https://api.spotify.com/v1/artists/0NawbOjd35MZ0vbymRBsV6'},
#  {'artist_id': '77SW9BnxLY8rJ0RciFqkHh',
#   'artist_name': 'The Neighbourhood',
#   'external_url': 'https://api.spotify.com/v1/artists/77SW9BnxLY8rJ0RciFqkHh'},
#  {'artist_id': '75kuF2ZXdfEQfgJATNsUBA',
#   'artist_name': 'Weezy.records',
#   'external_url': 'https://api.spotify.com/v1/artists/75kuF2ZXdfEQfgJATNsUBA'},
#  {'artist_id': '263iiWvJFev2CFa99uQ1wx',
#   'artist_name': 'Ryder',
#   'external_url': 'https://api.spotify.com/v1/artists/263iiWvJFev2CFa99uQ1wx'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '0sjSI5gElBjbSHCC26EVbD',
#   'artist_name': 'Nainoa Seitz',
#   'external_url': 'https://api.spotify.com/v1/artists/0sjSI5gElBjbSHCC26EVbD'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'external_url': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '4Vco08oleBJvFDzhpee4r7',
#   'artist_name': 'Sean Kennedy',
#   'external_url': 'https://api.spotify.com/v1/artists/4Vco08oleBJvFDzhpee4r7'},
#  {'artist_id': '25uiPmTg16RbhZWAqwLBy5',
#   'artist_name': 'Charli xcx',
#   'external_url': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '5QLqFZrUpEcA7eNeKdrDcN',
#   'artist_name': 'Ale Ranzani',
#   'external_url': 'https://api.spotify.com/v1/artists/5QLqFZrUpEcA7eNeKdrDcN'},
#  {'artist_id': '3DeOmVSmpv7WknXoo1OS8p',
#   'artist_name': 'Alleh',
#   'external_url': 'https://api.spotify.com/v1/artists/3DeOmVSmpv7WknXoo1OS8p'},
#  {'artist_id': '4eq1q0o9XPyNq9RG3fNDD1',
#   'artist_name': 'Yorghaki',
#   'external_url': 'https://api.spotify.com/v1/artists/4eq1q0o9XPyNq9RG3fNDD1'},
#  {'artist_id': '7v3tW6WmtJUMBVD5xkw1RV',
#   'artist_name': 'LINN',
#   'external_url': 'https://api.spotify.com/v1/artists/7v3tW6WmtJUMBVD5xkw1RV'},
#  {'artist_id': '250b0Wlc5Vk0CoUsaCY84M',
#   'artist_name': 'JENNIE',
#   'external_url': 'https://api.spotify.com/v1/artists/250b0Wlc5Vk0CoUsaCY84M'},
#  {'artist_id': '6USv9qhCn6zfxlBQIYJ9qs',
#   'artist_name': 'Dominic Fike',
#   'external_url': 'https://api.spotify.com/v1/artists/6USv9qhCn6zfxlBQIYJ9qs'},
#  {'artist_id': '7v3tW6WmtJUMBVD5xkw1RV',
#   'artist_name': 'LINN',
#   'external_url': 'https://api.spotify.com/v1/artists/7v3tW6WmtJUMBVD5xkw1RV'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '6TPfrqH7E4GUGnQdvcz5Gp',
#   'artist_name': 'Edvin Stais',
#   'external_url': 'https://api.spotify.com/v1/artists/6TPfrqH7E4GUGnQdvcz5Gp'},
#  {'artist_id': '4pdoRs7yHNXakMobf8M9Oz',
#   'artist_name': 'SASAMI',
#   'external_url': 'https://api.spotify.com/v1/artists/4pdoRs7yHNXakMobf8M9Oz'},
#  {'artist_id': '3l0CmX0FuQjFxr8SK7Vqag',
#   'artist_name': 'Clairo',
#   'external_url': 'https://api.spotify.com/v1/artists/3l0CmX0FuQjFxr8SK7Vqag'},
#  {'artist_id': '4yWTvglBOIXRq2Ah5lzWXs',
#   'artist_name': 'WILEYN',
#   'external_url': 'https://api.spotify.com/v1/artists/4yWTvglBOIXRq2Ah5lzWXs'},
#  {'artist_id': '7A0awCXkE1FtSU8B0qwOJQ',
#   'artist_name': 'Jamie xx',
#   'external_url': 'https://api.spotify.com/v1/artists/7A0awCXkE1FtSU8B0qwOJQ'},
#  {'artist_id': '7IfculRW2WXyzNQ8djX8WX',
#   'artist_name': 'Erykah Badu',
#   'external_url': 'https://api.spotify.com/v1/artists/7IfculRW2WXyzNQ8djX8WX'},
#  {'artist_id': '2v1OmkkSB3aa36LY8IV4JB',
#   'artist_name': 'Matteria',
#   'external_url': 'https://api.spotify.com/v1/artists/2v1OmkkSB3aa36LY8IV4JB'},
#  {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'artist_name': 'Latto',
#   'external_url': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '7bRPd812QoqCzYx2cLKoS2',
#   'artist_name': 'WHENSDAY',
#   'external_url': 'https://api.spotify.com/v1/artists/7bRPd812QoqCzYx2cLKoS2'},
#  {'artist_id': '2x7PC78TmgqpEIjaGAZ0Oz',
#   'artist_name': 'Trueno',
#   'external_url': 'https://api.spotify.com/v1/artists/2x7PC78TmgqpEIjaGAZ0Oz'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'external_url': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '1vJnJhKfJo2kkp1GbdtHBr',
#   'artist_name': 'Saltforest',
#   'external_url': 'https://api.spotify.com/v1/artists/1vJnJhKfJo2kkp1GbdtHBr'},
#  {'artist_id': '41E6bzHbZmzXWWNtcaq9QM',
#   'artist_name': 'Odiess',
#   'external_url': 'https://api.spotify.com/v1/artists/41E6bzHbZmzXWWNtcaq9QM'},
#  {'artist_id': '7pwufEBGfggjoI8twqlsmQ',
#   'artist_name': 'Nessa Barrett',
#   'external_url': 'https://api.spotify.com/v1/artists/7pwufEBGfggjoI8twqlsmQ'},
#  {'artist_id': '4Vco08oleBJvFDzhpee4r7',
#   'artist_name': 'Sean Kennedy',
#   'external_url': 'https://api.spotify.com/v1/artists/4Vco08oleBJvFDzhpee4r7'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name' :song_name, 'duration_ms':song_duration, 'url':song_url,
                     'popularity' :song_popularity, 'song_added' :song_added, 'album_id' :album_id,
                     'artist_id' :artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id            album_name release_date  total_tracks  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16             1
# 1  5K79FLRUCSysQnVESLcTdb  DeBÍ TiRAR MáS FOToS   2025-01-05            17
# 2  7kFyd5oyJdVX2pIi6P4iHE                 rosie   2024-12-06            12
# 3  1qHV8NvD3illdTOBxHdzru                   All   2025-01-17             1
# 4  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/5K79FLRUCSysQnV...
# 2  https://open.spotify.com/album/7kFyd5oyJdVX2pI...
# 3  https://open.spotify.com/album/1qHV8NvD3illdTO...
# 4  https://open.spotify.com/album/7aJuG4TFXa2hmE4...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   album_name    100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id artist_name  \
# 0  1HY2Jd0NmPuamShAr6KMms   Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C  Bruno Mars
# 2  4q3ewBCX7sLwd24euuV69X   Bad Bunny
# 3  3eVa5w3URK5duf6eyVDbu9        ROSÉ
# 4  0du5cEVh5yTK9QJze8zA0C  Bruno Mars
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/4q3ewBCX7sL...
# 3  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 4  https://api.spotify.com/v1/artists/0du5cEVh5yT...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id           song_name  duration_ms  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile       251667
# 1  3sK8wGT43QFpWrvNQsrQya                DtMF       237117
# 2  4wJ5Qq0jBN4ajy7ouZIV1c                APT.       169917
# 3  6IHb9PMB9Xqw3igHksDQxt                 All       157000
# 4  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER       210373
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...          99
# 1  https://open.spotify.com/track/3sK8wGT43QFpWrv...          98
# 2  https://open.spotify.com/track/4wJ5Qq0jBN4ajy7...          91
# 3  https://open.spotify.com/track/6IHb9PMB9Xqw3ig...          22
# 4  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          96
#
#              song_added                album_id               artist_id
# 0  2025-01-30T13:39:55Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# 1  2025-01-30T13:39:55Z  5K79FLRUCSysQnVESLcTdb  4q3ewBCX7sLwd24euuV69X
# 2  2025-01-30T13:39:55Z  7kFyd5oyJdVX2pIi6P4iHE  3eVa5w3URK5duf6eyVDbu9
# 3  2025-01-30T13:39:55Z  1qHV8NvD3illdTOBxHdzru  5S9g7xtHqKL3NQYfOdBBPO
# 4  2025-02-06T13:42:05Z  7aJuG4TFXa2hmE4z1yxc3n  6qqNVTkY8uBg9cP3Jd7DAH

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
